# %%
import time

# %%
def selection_sort(lst):
    for value in range(len(lst) - 1):
        tmp = lst[value]
        pos = value
        for counter in range(value+1, len(lst)):
            if lst[counter] < tmp:
                tmp = lst[counter]
                pos = counter

        old = lst[value]
        lst[value] = tmp
        lst[pos] = old
        
    return lst

# %%
def insertion_sort(lst):
    for i in range(1, len(lst)):
        for j in range(0, i):
            if (lst[i] < lst[j]):
                item = lst.pop(i)
                lst.insert(j, item)
                
    return lst

# %%
def bubble_sort(lst):
    for j in range(0, len(lst) - 1):
        counter = 0
        for i in range(0, len(lst) - 1):
            if (lst[i] > lst[i+1]):
                counter += 1
                tmp = lst[i]
                lst[i] = lst[i+1]
                lst[i+1] = tmp
        
        if counter == 0:
            break
                
    return lst

# %%
def merge(my_left, my_right):
    result = []
    pos_left = 0
    pos_right = 0
    
    while pos_left < len(my_left) and pos_right < len(my_right):
        if my_left[pos_left] < my_right[pos_right]:
            result.append(my_left[pos_left])
            pos_left += 1
        else:
            result.append(my_right[pos_right])
            pos_right += 1
            
    while pos_left < len(my_left):
        result.append(my_left[pos_left])
        pos_left += 1
    
    while pos_right < len(my_right):
        result.append(my_right[pos_right])
        pos_right += 1
        
    return result

# %%
def merge_sort(lst):
    if len(lst) == 1:
        return lst
    
    left = lst[0:len(lst)//2]
    right = lst[len(lst)//2:]
    
    left = merge_sort(left)
    right = merge_sort(right)
    
    return merge(left, right)

# %%
import numpy

# %%
size = []
ins = []
sel = []
bub = []
mer = []

# %%
for step in range(2, 20):
    lst_size = 1000 * step 

    this_list = list(numpy.random.randint(0, lst_size, lst_size))
    
    t1 = time.perf_counter()
    insertion_sort(this_list)
    t_ins = time.perf_counter() - t1

    t1 = time.perf_counter()
    selection_sort(this_list)
    t_sel = time.perf_counter() - t1

    t1 = time.perf_counter()
    bubble_sort(this_list)
    t_bub = time.perf_counter() - t1

    t1 = time.perf_counter()
    merge_sort(this_list)
    t_mer = time.perf_counter() - t1
    
    print(lst_size, t_ins, t_sel, t_bub, t_mer)
# Out:
# 2000 0.4358647999999903 0.42945829999996477 0.00047449999999571446 0.019935199999963515
# 3000 1.3549569000000474 0.5220995999999332 0.0006690999999818814 0.02140729999996438
# 4000 0.886240500000099 0.6859871999999996 0.0005919999999832726 0.019104100000049584
# 5000 2.624846199999979 1.7259921000000986 0.0011076000000684871 0.03382290000001831
# 6000 4.363264200000003 2.8103912000000264 0.001156400000013491 0.027936699999941084
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 11
#       8 t_ins = time.perf_counter() - t1
#      10 t1 = time.perf_counter()
# ---> 11 selection_sort(this_list)
#      12 t_sel = time.perf_counter() - t1
#      14 t1 = time.perf_counter()
#
# Cell In [2], line 6, in selection_sort(lst)
#       4 pos = value
#       5 for counter in range(value+1, len(lst)):
# ----> 6     if lst[counter] < tmp:
#       7         tmp = lst[counter]
#       8         pos = counter
#
# KeyboardInterrupt:

# %%
for step in range(1, 20):
    lst_size = 1000 * step 
    size.append(lst_size)

    this_list = list(numpy.random.randint(0, lst_size, lst_size))
    
    t1 = time.perf_counter()
    insertion_sort(this_list)
    t_ins = time.perf_counter() - t1
    ins.append(t_ins)

    t1 = time.perf_counter()
    selection_sort(this_list)
    t_sel = time.perf_counter() - t1
    sel.append(t_sel)

    t1 = time.perf_counter()
    bubble_sort(this_list)
    t_bub = time.perf_counter() - t1
    bub.append(t_bub)

    t1 = time.perf_counter()
    merge_sort(this_list)
    t_mer = time.perf_counter() - t1
    mer.append(t_mer)
    
    print(lst_size, t_ins, t_sel, t_bub, t_mer)
# Out:
# 1000 0.1396968999999899 0.10275010000009388 0.0003025000000889122 0.004943099999991318
# 2000 0.36739490000002206 0.3119712000000163 0.000366099999951075 0.014298400000029687
# 3000 1.1543646999999737 0.7211997999999085 0.0006498000000192405 0.027604999999994106
# 4000 1.8871893999998974 1.7874871999999868 0.0011182999999164167 0.053696200000104
# 5000 2.462360999999987 1.6811913000000231 0.0027273000000604952 0.14625210000008337
# 6000 3.4385088000000223 2.7488499999999476 0.0009932000000389962 0.038243699999952696
# 7000 4.211833400000046 3.617093899999986 0.0015707999999676758 0.04521020000004228
# 8000 6.020826800000009 4.564482999999996 0.002035800000044219 0.0784764999999652
# 9000 7.264935199999968 5.24282699999992 0.0016888999999764565 0.06164740000008351
# 10000 7.890037799999959 5.543914900000004 0.003635000000031141 0.10278999999991356
# 11000 12.711112800000024 15.034248699999921 0.005636500000036904 0.1567766999999094
# 12000 20.949255100000073 15.382393300000103 0.0024263000000246393 0.15909919999990052
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 8
#       5 this_list = list(numpy.random.randint(0, lst_size, lst_size))
#       7 t1 = time.perf_counter()
# ----> 8 insertion_sort(this_list)
#       9 t_ins = time.perf_counter() - t1
#      10 ins.append(t_ins)
#
# Cell In [3], line 6, in insertion_sort(lst)
#       4         if (lst[i] < lst[j]):
#       5             item = lst.pop(i)
# ----> 6             lst.insert(j, item)
#       8 return lst
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
x_sqr = [item **2 for item in size]

# %%
plt.plot(x_sqr)

# %%
plt.plot(size, x_sqr, label = 'x^^2')

# %%
plt.plot(size, x_sqr, label='$x^2$')
plt.legend()
plt.show()

# %%
plt.plot(size, ins, label='insertion')
plt.plot(size, sel, label='selection')
plt.plot(size, bub, label='bubble')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 plt.plot(size, ins, label='insertion')
#       2 plt.plot(size, sel, label='selection')
#       3 plt.plot(size, bub, label='bubble')
#
# File c:\Users\Asus\anaconda3\lib\site-packages\matplotlib\pyplot.py:2840, in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1743, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1512 """
#    1513 Plot y versus x as lines and/or markers.
#    1514
#    (...)
#    1740 (``'green'``) or hex strings (``'#008000'``).
#    1741 """
#    1742 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744 for line in lines:
#    1745     self.add_line(line)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\matplotlib\axes\_base.py:273, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     271     this += args[0],
#     272     args = args[1:]
# --> 273 yield from self._plot_args(this, kwargs)
#
# File c:\Users\Asus\anaconda3\lib\site-packages\matplotlib\axes\_base.py:399, in _process_plot_var_args._plot_args(self, tup, kwargs)
#     396     self.axes.yaxis.update_units(y)
#     398 if x.shape[0] != y.shape[0]:
# --> 399     raise ValueError(f"x and y must have same first dimension, but "
#     400                      f"have shapes {x.shape} and {y.shape}")
#     401 if x.ndim > 2 or y.ndim > 2:
#     402     raise ValueError(f"x and y can be no greater than 2-D, but have "
#     403                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (13,) and (12,)

# %%
plt.plot(size, bubf, label='bubble fast')
plt.plot(size, mer, label='merge')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 plt.plot(size, bubf, label='bubble fast')
#       2 plt.plot(size, mer, label='merge')
#       3 plt.legend()
#
# NameError: name 'bubf' is not defined
